# %% [markdown]
# # matplotilb  중급

# %% [markdown]
# ## 시스템 점검

# %%
import sys
sys.version
# Out:
# '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]'

# %% [markdown]
# ## plot() 복습
# - 한글처리

# %%
import matplotlib.pyplot as plt

mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

plt.plot([1,2,3,4],[10,20,30,40])
plt.title('plotting')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5032\1397784065.py in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 mpl.rc('font', family='Malgun Gothic')
#       4 mpl.rc('axes', unicode_minus=False)
#       5
#
# NameError: name 'mpl' is not defined

# %% [markdown]
# ## FIGSIZE

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,2))
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.plot([-2,-1,0,1,2,3],[20,30,15,40,45,35], label='선 1')
plt.plot([-2,-1,0,1,2,3],[-25,10,35,20,15,25], label='선 2')
plt.title('선 그래프 예제')
plt.xlabel('x 축')
plt.ylabel('y 축')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

plt.hist([1,1,2,3,4,5,6,6,7,8,10])
plt.show()

# %% [markdown]
# ## histogram 도수분포표

# %%
import matplotlib.pyplot as plt

plt.hist([1,1,2,3,4,5,6,6,7,8,10], rwidth=0.9)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist([1,1,2,3,4,5,6,6,7,8,10], rwidth=0.9)
plt.show()

# %% [markdown]
# ## random.randint(a,b)

# %%
import random
random.randint(1,6)
# Out:
# 3

# %%
import random
random.randrange(1,6)
# Out:
# 4

# %%
import random as rd

dice = []
for i in range(5):
    dice.append(rd.randint(1,6))
    
dice
# Out:
# [6, 3, 1, 4, 6]

# %% [markdown]
# ## 리스트 컴프리헨션

# %%
dice =[rd.randint(1,6) for i in range(5)]
dice
# Out:
# [1, 4, 2, 2, 4]

# %%
import random

dice = []

for i in range(1000):
    dice.append(random.randint(1,6))
    
plt.hist(dice, bins=6)
plt.show()

# %%
rd.choices(range(1,7), k=5)
# Out:
# [3, 2, 2, 2, 6]

# %% [markdown]
# ## plt.subplot()

# %%
import matplotlib.pyplot as plt
import random

result = []
for i in range(13):
    result.append(random.randint(1,1000))
    
print(sorted(result))

plt.boxplot(result)
plt.show()
# Out:
# [220, 229, 290, 303, 375, 427, 630, 857, 876, 896, 914, 973, 999]

# %%
import matplotlib.pyplot as plt
import random

result1 = []
result2 = []
for i in range(13):
    result1.append(random.randint(1,500))
    result2.append(random.randint(501,1000))

plt.boxplot(result1)
plt.boxplot(result2)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

result1 = []
result2 = []
for i in range(13):
    result1.append(random.randint(1,500))
    result2.append(random.randint(501,1000))

plt.boxplot([result1 , result2])
plt.show()

# %% [markdown]
# ## plt.figure(figsize=(m,n))

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)

f1 = plt.figure(figsize=(10,2))
plt.plot(np.random.randn(100))

plt.title("figure size : (10,2) ")
plt.show()

# %% [markdown]
# ## plt.subplot()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,3))
plt.subplot(2,3,1)
plt.subplot(2,3,5)
plt.subplot(2,3,6)
# Out:
# <AxesSubplot:>

# %%
ax1 = plt.subplot(2,1,1)
plt.plot(np.random.randint(1,10,10), 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
print(ax1)

ax2 = plt.subplot(2,1,2)
plt.plot(np.arange(10), np.arange(10)*2,'r-')
plt.xlabel('time (s)')
plt.ylabel('Damped oscillation')
print(ax2)

plt.tight_layout()
plt.show()
# Out:
# AxesSubplot(0.125,0.53;0.775x0.35)
# AxesSubplot(0.125,0.11;0.775x0.35)

# %% [markdown]
# ## plt.subplots()

# %%
import matplotlib.pyplot as plt

fig. axes = plt.subplots(2,2)

axes[0,0].plot()
axes[0,1].plot()
axes[1,0].plot()
axes[1,1].plot()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5032\398162411.py in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 fig. axes = plt.subplots(2,2)
#       4
#       5 axes[0,0].plot()
#
# NameError: name 'fig' is not defined

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2,2)

axes[0,0].plot([1,2,3,4])
axes[0,0].set_title("Subplot 1")

axes[0,1].plot([4,3,2,1])
axes[0,1].set_title("Subplot 2")

axes[1,0].hist([1,2,2,3,3,3,4,4,4,4], bins=5)
axes[1,0].set_title("Subplot 3")

axes[1,1].scatter([1,2,3,4],[4,3,2,1])
axes[1,1].set_title("Subplot 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## fig.add_subplot()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,5))
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
fig = plt.figure(figsize=(7,5))
ax2 = fig.add_subplot(2,2,2)
plt.plot(np.random.randn(50).cumsum(), 'k--')
ax3 = fig.add_subplot(2,2,3)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,5))
ax2 = fig.add_subplot(2,2,2)
plt.plot(np.random.randn(50).cumsum(), 'g--')



ax3 = fig.add_subplot(2,2,3)
plt.plot(np.random.randn(50), 'm--')
